# %%
def scalar_multiply(matrix: list[list[int|float]], scalar: int|float) -> list[list[int|float]]:
    for i in range(len(matrix)):
        for j in range(len(matrix[0])):
            matrix[i][j] *= scalar
    
    return matrix


scalar_multiply([[1, 2], [3, 4]], scalar = 2)
# Out:
# [[2, 4], [6, 8]]

# %%
scalar_multiply([[1, 2], [3, 4]], scalar = 2)
# Out:
# [[2, 4], [6, 8]]
